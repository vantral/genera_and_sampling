# %%
import pandas as pd
from anytree import Node, RenderTree, NodeMixin
from anytree.search import findall
from itertools import combinations
from tqdm.notebook import tqdm

# %%
class NodeWithGenus(NodeMixin):
    def __init__(self, name, genus=None, parent=None, confidence=None):
        self.name = name
        self.genus = genus
        self.parent = parent
        self.confidence = confidence
    def __repr__(self):
        return f'Node {self.name}, Genus {self.genus}'

def find_common_ancestor(node1, node2):
    anc1 = list(node1.ancestors)
    anc2 = list(node2.ancestors)
    
    anc1.reverse()
    anc2.reverse()
    
    for i in anc1:
        for j in anc2:
            if i == j:
                return i

# %%
wals = pd.read_csv('wals_languages.csv')
wals.at[2296,'Glottocode'] = 'shah1254'
genera = wals[['Genus', 'Glottocode']].dropna()
genera = pd.Series(genera.Genus.values,index=genera.Glottocode).to_dict()

# %%
wals.query('Genus == "Yaruro"')
# Out:
#        ID    Name      Macroarea  Latitude  Longitude Glottocode ISO639P3code  \
# 2614  yrr  Yaruro  South America       7.0      -68.0   pume1238          yae
#
#       Family Subfamily   Genus GenusIcon ISO_codes Samples_100 Samples_200  \
# 2614  Yaruro       NaN  Yaruro       NaN       yae       False       False
#
#      Country_ID               Source     Parent_ID
# 2614         VR  Mosonyi-et-al-2000a  genus-yaruro

# %%
glottolog_parsed = pd.read_csv('languages_with_pages.tsv', sep='\t', index_col=0)
paths = glottolog_parsed.path
language_list = glottolog_parsed.glottocode.to_list()

# %%
nodes = {}
lst = [path.split('/') for path in paths]

for path in lst:
    for i, par in enumerate(path):
        nk = nodes[par] = nodes.get(par) or NodeWithGenus(par, genera.get(par, None))
        if i != 0:
            nv = nodes[path[i - 1]] = nodes.get(path[i - 1]) or NodeWithGenus(path[i - 1], genera.get(path[i - 1], None))
            nk.parent = nv
            
[root] = [n for n in nodes.values() if n.parent is None]

# %%
leaves = root.descendants
leaves = [leaf for leaf in leaves if leaf.name in language_list]
sum([x.genus is not None for x in leaves]) / len(leaves)
# Out:
# 0.2809512706924691

# %%
leaves = root.descendants

for leaf in leaves:
    if leaf.genus:
        leaf.confidence = 'initial'
    if leaf.parent == root:
        leaf.genus = 'isolate'

# %%
for genus in tqdm(wals.Genus.dropna().unique()):
    if genus in ['Creoles and Pidgins', 'Sign Languages']:
        continue
    # Creoles and Pidgins as well as Sign Languages do not form a genealogical genus
    
    langs = findall(root, filter_=lambda node: node.genus == genus)
    # Find all languages with the same genus
    
    print(genus, len(langs))
    
    pairs = combinations(langs, 2)
    # Make all possible combinations
    
    all_nodes = list(root.descendants)
    
    for node1, node2 in pairs:
        anc = find_common_ancestor(node1, node2)
        # find the first common ancestor
        
        if anc.name in ['uncl1493', 'book1242']:
            continue
        
        # if an ancestor has already been taken into account it is removed from the list
        if anc not in all_nodes:
            continue
        else:
            all_nodes.remove(anc)
        
        for des in anc.descendants:
            if des.genus and des.genus != genus:
                # if any descendant has another genus, nothing is changed
                break
        else:
            for des in anc.descendants:
                if des.genus:
                    continue
                des.genus = genus
                des.confidence = f'common ancestor ({node1.name}, {node2.name})'
# Out:
#   0%|          | 0/625 [00:00<?, ?it/s]
# Kombio-Arapesh 4
# South Omotic 3
# Abau 1
# Semitic 32
# Agneby 2
# Abipon 1
# Northwest Caucasian 5
# Muskogean 6
# Central Pama-Nyungan 15
# Lowland East Cushitic 12
# Abun 0
# Alor-Pantar 6
# Algonquian 28
# Malayo-Sumbawan 20
# Japura-Colombia 8
# Maweti-Guarani 16
# Mayan 27
# Western Nilotic 10
# Achumawi 1
# Burmese-Lolo 14
# Keresan 2
# Jivaroan 4
# Andoke 0
# Oceanic 146
# Aleut 1
# Germanic 19
# Gauwa 5
# Upper Cross 2
# Greater Central Philippine 19
# Wide Grassfields 13
# Lezgic 9
# Angami-Pochuri 3
# Northern Pama-Nyungan 32
# Southern Cushitic 5
# Athapaskan 22
# Awju 2
# Aikaná 0
# Ainu 1
# Kru 9
# Kresh 2
# Gbe 4
# Bantu 128
# Great Andamanese 4
# Tano 7
# Northern Caddoan 4
# Cariban 17
# Sepik Hill 3
# Albanian 0
# Huarpe 1
# Avikam-Alladian 2
# Central Malayo-Polynesian 29
# Alsea 0
# Northern Chukotko-Kamchatkan 4
# Mara 3
# Northwest Sumatra-Barrier Islands 8
# Ndu 5
# Panoan 11
# Bodic 31
# Mabuso 3
# East Formosan 2
# Harakmbet 1
# Left May 2
# Border 5
# Central Kainji 2
# South Halmahera - West New Guinea 10
# Yanesha' 1
# Josephstaal 1
# Amuzgoan 1
# Tacanan 4
# West Chadic 14
# Anêm 0
# Senagi 2
# Khoe-Kwadi 6
# Anindilyakwa 1
# Nungish 3
# Angaataha 1
# Avar-Andic-Tsezic 13
# Central Naga 2
# Nuclear Angan 4
# Je Setentrional 3
# Tani 7
# Purus 2
# Antillean Arawakan 2
# Zaparoan 3
# South Bird's Head Proper 1
# Armenian 2
# Asmat-Kamrau Bay 2
# Turkic 33
# Indic 47
# Romance 17
# Atayalic 2
# South Sulawesi 10
# Himalayish 19
# Atakapa 0
# Kunza 0
# Eskimo 9
# Atsugewi 1
# Central Wapei 2
# Moru-Ma'di 5
# Ka-Togo 2
# Elevala 1
# Central Cushitic 3
# Barbacoan 4
# Ram 1
# Aymaran 2
# Jirajaran 0
# Zamucoan 1
# Koiarian 5
# Wandjiginy 0
# Bongo-Bagirmi 11
# Negro-Roraima 2
# Macro-Bai 1
# Sama-Bajaw 5
# Ubangi 16
# Western Mande 18
# Biu-Mandara 23
# Mongolic 11
# Bolivia-Parana 3
# Eastern Nilotic 5
# Kuki-Chin 13
# Marne 3
# Southeastern Pama-Nyungan 18
# Berber 13
# Bella Coola 1
# Dravidian 20
# Western Pama-Nyungan 43
# West Bomberai 2
# Siane-Yagaria 4
# North Borneo 11
# Beja 1
# Beothuk 0
# Berta 0
# Jaad 1
# Celebic 12
# Guaymiic 2
# Bangime 0
# Kho-Bwa 3
# Northern Mel 2
# Munda 9
# East Chadic 7
# Bilua 0
# Binanderean 4
# Kwomtari 2
# Bilic 2
# Benue-Congo Plateau 7
# Eastern Mande 8
# Land Dayak 3
# Iranian 25
# Northern Luzon 11
# South Surmic 8
# Slavic 15
# Ohio Valley Siouan 2
# Balanta 1
# Oti-Volta 13
# Huon 5
# Arauan 3
# Bunuban 2
# Baining 2
# Edoid 8
# Tairora 2
# Tucanoan 18
# Sangiric 4
# Alto-Orinoco 1
# Boazi 2
# Brahmaputran 10
# Rai Coast 3
# Boran 2
# Bahnaric 14
# Basque 0
# Baatonum 1
# Western Isthmic Chibchan 4
# Nyulnyulan 5
# Celtic 6
# Highland East Cushitic 2
# Tor-Orya 2
# Warapu 1
# Bororoan 1
# Katuic 4
# Birri 1
# Tenda 2
# Betoi 0
# Burarran 2
# South Bougainville 3
# Burushaski 0
# Geelvink Bay 1
# Cacua-Nukak 2
# Caddo 1
# Northern Uto-Aztecan 12
# Camsá 0
# Candoshi 0
# Choco 5
# Pre-Andine Arawakan 4
# Chumash 2
# Popolocan 7
# Chinantecan 7
# Yuman 7
# Chamorro 1
# Lower Sepik 3
# Nakh 3
# Southern Iroquoian 1
# Chimariko 0
# Tsamosan 1
# Tequistlatecan 2
# Zapotecan 13
# Matacoan 4
# Cahuapanan 2
# Chichimec 1
# Chinookan 3
# Central Salish 8
# Hobitu-Cholon 0
# Chimila 1
# Comecrudan 0
# Chimakuan 2
# Katukinan 1
# Chinese 6
# Coahuiltecan 0
# Interior Salish 8
# Cofán 0
# Arhuacic 3
# Coosan 1
# Egyptian-Coptic 1
# Corachol 2
# Costanoan 1
# Uru-Chipaya 2
# Chiquitano 1
# Missouri River Siouan 2
# Jola 2
# Cuicatec 1
# Chitimacha 0
# Catawban 1
# Timote-Cuica 0
# Guahiban 5
# Cuitlatec 0
# Chimbu-Wahgi 8
# Northern Iroquoian 7
# Cayuvava 0
# Teberan 2
# Dagan 1
# Dahalo 1
# Mississippi Valley Siouan 7
# Southern Nilotic 3
# Nadahup 3
# Day 1
# Daju 3
# Dogon 4
# Ijoid 2
# Dhimalic 1
# Digaroan 2
# Dizoid 1
# Djingili 1
# Dani 2
# Kam-Tai 12
# East Tariku 3
# Samba-Duru 3
# Dargwic 1
# Western Skou 2
# Duna 0
# Senufo 6
# Nupoid 2
# Bosavi 2
# Lower Cross 3
# Ega 1
# Mek 4
# Ekoid-Mbe 2
# Paniai Lakes 2
# Morwap 0
# Wagaydy 2
# Enga_Kewa-Huli 3
# Samoyedic 6
# Enggano 1
# Tacame 0
# Esselen 0
# Finnic 7
# Opata-Eudeve 1
# Tungusic 10
# Eyak 1
# Fasu 0
# Peul-Serer 6
# Foe 1
# Fore-Gimi 1
# Baibai-Fas 1
# Fulniô 0
# Fur 1
# Ga-Dangme 1
# Gaagudju 0
# Gade 1
# Gahuku 1
# Ta-Ne-Omotic 11
# Monde 1
# Gbaya-Manza-Ngbaka 5
# Greek 1
# Kartvelian 4
# Bua 2
# Tsimshianic 3
# Puelche 0
# Kadai 4
# North Halmaheran 8
# Gumuz 1
# Mascoian 2
# Worrorran 2
# Guajiro-Paraujano 1
# Gogodala 1
# Ogonoid 2
# Gola 1
# Tarahumaran 3
# Garrwan 1
# Guató 0
# Guhu-Samane 1
# Na-Qiangic 5
# Hadza 0
# Haida 1
# Piawi 1
# Hatim-Mansim 1
# Northern Wakashan 3
# Hmongic 3
# Witoto 4
# =|Hoan 1
# Ugric 3
# Huavean 1
# Central Tariku 1
# Idomoid 2
# Quechuan 11
# Igboid 2
# Eastern Jebel 1
# Kuliak 3
# Inanwatan 1
# Iranxe 0
# Krisa 1
# Defoid 2
# Isirawa 1
# Southern Chukotko-Kamchatkan 1
# Itonama 0
# Batanic 2
# Iwaidjan 2
# Iwamic 1
# Aslian 5
# Jaminjungan 1
# Javanese 1
# Jabutí 1
# Kiowa-Tanoan 5
# Talodi 2
# Japanese 2
# Yuruna 1
# South Andamanese 2
# Ju-Kung 2
# Jukunoid 2
# Karajá 1
# Ramarama 1
# Kadugli 1
# Tate 0
# Lampungic 2
# Lower Ramu 2
# Kaure 1
# Tangkic 3
# Zemeic 2
# Ap Ma 1
# Western Saharan 3
# Karen 5
# Grusi 9
# Songhay 3
# Kadiwéu 1
# Yeniseian 3
# Koromfe 1
# Khinalug 1
# Khmer 1
# Khasian 1
# Ruboni 2
# Jarrakan 2
# Kolopom 2
# Kirma-Tyurama 1
# Southern Mel 2
# Kiwaian 1
# West Tariku 1
# Karankawa 0
# Mbumic 5
# Klamath-Modoc 0
# Kalapuyan 1
# Kalam-Kobon 2
# Ndeiram 1
# Core Goilalan 2
# Nimboran 2
# Khmuic 3
# Eastern Daly 2
# Marienberg 1
# Arikem 1
# Kanum 2
# Je Meridional 2
# Kunama 0
# Kapixana 0
# North Bougainville 2
# Maiduan 3
# Koman 1
# Permic 3
# Korean 1
# Central Luzon 1
# Aimore 1
# Kariri 1
# Karok 0
# Becking-Dawi 1
# Pomoan 5
# Pearic 1
# Kim 1
# Ok 4
# Katla-Tima 2
# Nuristani 3
# Kuna 1
# Kuot 0
# Kusunda 0
# Kutenai 0
# Kwerba 1
# Nukuma 1
# Kwaza 0
# Mamfe 1
# Southern Wakashan 3
# Eastern Pauwasi 1
# Laal 0
# Lafofa 0
# Lak 1
# Masa 2
# Laragiya 0
# Baltic 2
# Lavukaleve 0
# Lendu 2
# Leko 0
# Mangbutu-Efe 2
# Hlai 1
# Na-Togo 1
# Limilngan 1
# Lobiri-Jaane 1
# Lule 0
# Maban 3
# Mari 2
# Majang 1
# Barito 3
# Araucanian 1
# Maxakalian 1
# Maybrat 0
# Otomian 5
# Bogia 1
# Mangbetu 1
# Mochica 0
# Mixe-Zoque 10
# Miwok 6
# Qom 3
# Mandan 1
# East Bird's Head 2
# Manipuri 1
# Tupari 1
# Eastern Trans-Fly 1
# Mailuan 1
# Tama Sepik 2
# Nubian 3
# Mienic 2
# Taman 3
# Kman-Meyor 1
# Karbic 1
# Misumalpan 2
# Mixtec 13
# Manjaku 2
# East Timor 1
# Bulaka River 2
# Máku 0
# Mambiloid 0
# Northern Daly 2
# Molala 0
# Mordvin 2
# Mombum 1
# Monic 2
# Mosetenan 0
# Movima 0
# Murrinh-Patha 1
# Mpur 0
# Somahai 1
# Marind-Yaqay 2
# Bringen 2
# Moraori 0
# Heiban 2
# Mairasic 1
# Chibcha-Duit 1
# Barí 1
# Bargam 1
# Mumuye-Yandang 1
# Vietic 2
# Munduruku 1
# Mangarrayi 1
# Cahita 2
# Yale 0
# Nahali 0
# Yellow River 1
# Nara 0
# Natchez 0
# Nicobarese 2
# Ndjébbana 1
# Cangin 3
# Tepiman 5
# Sahaptian 3
# Ngankikurungkurr 1
# Eastern Gunwinyguan 3
# Tangkhul-Maring 1
# Aztecan 12
# East Wapei 2
# Nivkh 1
# Nakkara 1
# Nambikuaran 1
# East Strickland 1
# Sogeram 1
# Finisterre 3
# Beboid 1
# Nunggubuyu 1
# Nyimang 1
# Central Delta 2
# Matlatzincan 1
# Oksapmin 1
# West Wapei 1
# Rashad 1
# Eleman 2
# Páezan 0
# Paiwan 1
# Palauan 1
# Pamean 1
# Pawaian 0
# Pech 1
# Maco-Piaroa 1
# Palaungic 2
# Palikur 1
# Serra Hills 2
# Central Arawakan 2
# Mura 0
# Wintuan 2
# Puinave 0
# Puquina 0
# Tarascan 1
# Alacalufan 1
# Rama 1
# Rao 1
# Rejang 1
# Rikbaktsa 1
# Raji-Raute 1
# Rukai 1
# Turama-Kikorian 1
# Salinan 0
# Sáliba 1
# Saami 3
# Sandawe 0
# Chonan Proper 2
# Seri 0
# Shabo 0
# Yanomam 3
# Shasta 1
# Siuslawan 0
# Siamou 0
# Shompen 0
# Sentanic 2
# Suki 1
# Sulka 0
# Savosavo 0
# Taiap 0
# Totonacan 6
# West Bird's Head 1
# Western Plains Austronesian 1
# Ticuna 1
# Tikar 1
# Tillamook 1
# Tivoid 1
# Tiwian 0
# Takelma 0
# Tlingit 1
# Taulil 1
# Subtiaba-Tlapanec 1
# Timucua 0
# Kayagar 1
# Temein 1
# Tunebo 1
# Minahasan 2
# Tol 1
# Tonkawa 0
# Tusia 1
# Tasmanian 0
# Trique 2
# Trumai 0
# Tsou 1
# Taushiro 0
# Tubar 1
# Tunica 0
# Urim 1
# Urarina 0
# Urat 1
# North Adelbert 1
# Wagiman 0
# West Palei 1
# Wambayan 1
# Waorani 0
# Wappo 1
# Chapacura-Wanham 1
# Washo 0
# Dumut 1
# Yokuts 1
# Wiyot 1
# Wolof 1
# Wogamusin-Chenapian 1
# Warao 0
# Yangmanic 1
# Western Gunwinyguan 1
# Kowan 1
# Tu 2
# Je Central 2
# Peba-Yaguan 1
# Yámana 0
# Yana 0
# Yapese 1
# Yareban 1
# Yawa 1
# Yei 1
# Yele 0
# Yuki 1
# Yukaghir 2
# Yuracare 0
# Yurimangí 0
# Yaruro 0
# Yuchi 0
# Yurok 1
# Eastern Saharan 1
# Zuni 0

# %%
leaves = root.descendants
leaves = [leaf for leaf in leaves if leaf.name in language_list]
sum([x.genus is not None for x in leaves]), len(leaves)
# Out:
# (6506, 8578)

# %%
leaves = root.descendants
leaves = [leaf for leaf in leaves if leaf.name in language_list]
sum([x.genus is not None for x in leaves]) / len(leaves)
# Out:
# 0.7584518535789229

# %%
final_df = [
    {
        'glottocode': x.name,
        'genus': x.genus,
        'confidence': x.confidence
    } for x in leaves
]

pd.DataFrame(final_df).to_csv('final_genera_75.tsv', sep='\t', index=False)

# %%
# for node in tqdm(root.descendants):
#     if node.name not in language_list:
#         continue
#     if node.parent.name in ['uncl1493', 'root', 'book1242']:
#         continue
#     if not node.genus or node.genus in ['Creoles and Pidgins', 'Sign Languages']:
#         continue
#     # Creoles and Pidgins as well as Sign Languages do not form a genealogical genus
    
#     siblings = node.siblings
    
#     for sibling in siblings:
#         if sibling.genus and sibling.genus != node.genus:
#             # if any sibling has another genus, nothing is changed
#             break
#     else:
#         for sibling in siblings:
#             if sibling.genus or sibling.name not in language_list:
#                 continue
#             sibling.genus = node.genus
#             sibling.confidence = f'sibling of {node.name}'

# leaves = root.descendants
# leaves = [leaf for leaf in leaves if leaf.name in language_list]
# sum([x.genus is not None for x in leaves]) / len(leaves)
# Out:
#   0%|          | 0/13324 [00:00<?, ?it/s]
